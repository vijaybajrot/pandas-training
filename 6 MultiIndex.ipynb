# %%
import pandas as pd

# %%
bigmac = pd.read_csv("files/bigmac.csv", parse_dates=['Date'])

# %%
bigmac
# Out:
#           Date        Country  Price in US Dollars
# 0   2016-01-01      Argentina                 2.39
# 1   2016-01-01      Australia                 3.74
# 2   2016-01-01         Brazil                 3.35
# 3   2016-01-01        Britain                 4.22
# 4   2016-01-01         Canada                 4.14
# ..         ...            ...                  ...
# 647 2010-01-01         Turkey                 3.83
# 648 2010-01-01            UAE                 2.99
# 649 2010-01-01        Ukraine                 1.83
# 650 2010-01-01  United States                 3.58
# 651 2010-01-01        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# #### Create a MultiIndex on a DataFrame with the set_index Method

# %%
bigmac.set_index("Date")
# Out:
#                   Country  Price in US Dollars
# Date
# 2016-01-01      Argentina                 2.39
# 2016-01-01      Australia                 3.74
# 2016-01-01         Brazil                 3.35
# 2016-01-01        Britain                 4.22
# 2016-01-01         Canada                 4.14
# ...                   ...                  ...
# 2010-01-01         Turkey                 3.83
# 2010-01-01            UAE                 2.99
# 2010-01-01        Ukraine                 1.83
# 2010-01-01  United States                 3.58
# 2010-01-01        Uruguay                 3.32
#
# [652 rows x 2 columns]

# %%
bigmac.set_index(keys=["Date", "Country"])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
bigmac.set_index(keys=["Country", "Date"])
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2016-01-01                 2.39
# Australia     2016-01-01                 3.74
# Brazil        2016-01-01                 3.35
# Britain       2016-01-01                 4.22
# Canada        2016-01-01                 4.14
# ...                                       ...
# Turkey        2010-01-01                 3.83
# UAE           2010-01-01                 2.99
# Ukraine       2010-01-01                 1.83
# United States 2010-01-01                 3.58
# Uruguay       2010-01-01                 3.32
#
# [652 rows x 1 columns]

# %%
bigmac.nunique()
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
bigmac.set_index(keys=["Date","Country"], inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]

# type(bigmac.index[0])
# Out:
# tuple

# %% [markdown]
# #### Extract Index Level Values with the get_level_values Method

# %%
bigmac.index.get_level_values('Date')
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values('Country')

# bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# #### Change Index Level Name with the set_names Method

# %%
bigmac.index.set_names(names=['Day', 'Location'])

# bigmac.index.set_names(names=['Day', 'Location'], inplace=True)
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
#another option
bigmac.index.set_names('Day', level=0)
bigmac.index.set_names('Day', level='Date')
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %% [markdown]
# #### The sort_index Method on a MultiIndex DataFrame

# %%
bigmac.sort_index()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(ascending=True)
# bigmac.sort_index(ascending=False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
# order for each index

bigmac.sort_index(ascending=[True, False])
# bigmac.sort_index(ascending=[False,True])
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83
# ...                                       ...
# 2016-01-01 Brazil                        3.35
#            Belgium                       4.25
#            Austria                       3.76
#            Australia                     3.74
#            Argentina                     2.39
#
# [652 rows x 1 columns]

# %%
# Level wise

bigmac.sort_index(level=0, ascending=False)
# bigmac.sort_index(level="Date", ascending=False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %% [markdown]
# #### Extract Rows from a MultiIndex DataFrame

# %%
# using loc

# %%
# to get first/outer index only
bigmac.loc['2010-01-01']
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
# Here we are passing tuple to get row

bigmac.loc[('2010-01-01', 'Argentina')]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc[('2010-01-01', 'Argentina'), "Price in US Dollars"]
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2010-01-01', 'Argentina'), ["Price in US Dollars"]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84

# %%
bigmac.loc[('2010-01-01')]
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.loc[('2010-01-01',)]
# Out:
#                 Price in US Dollars
# Country
# Argentina                      1.84
# Australia                      3.98
# Brazil                         4.76
# Britain                        3.67
# Canada                         3.97
# Chile                          3.18
# China                          1.83
# Colombia                       3.91
# Costa Rica                     3.52
# Czech Republic                 3.71
# Denmark                        5.99
# Egypt                          2.38
# Euro area                      4.84
# Hong Kong                      1.91
# Hungary                        3.86
# Indonesia                      2.24
# Israel                         3.99
# Japan                          3.50
# Latvia                         3.09
# Lithuania                      2.87
# Malaysia                       2.08
# Mexico                         2.50
# New Zealand                    3.61
# Norway                         7.02
# Pakistan                       2.42
# ...

# %%
## Using iloc
# iloc will works same

# %%
bigmac.iloc[0]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.iloc[[0, 10, 50, 100]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Denmark                   5.99
# 2010-07-01 Colombia                  4.39
# 2011-07-01 Estonia                   3.15

# %%
bigmac.iloc[0:10]
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71

# %% [markdown]
# #### The transpose Method on a MultiIndex DataFrame

# %%
bigmac2 = bigmac.copy()

bigmac2 = bigmac2.transpose()
bigmac2
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac2.loc[('Price in US Dollars',), ("2010-01-01",)]
bigmac2.loc[('Price in US Dollars',), ("2010-01-01","Argentina")]


# type(bigmac2.loc[('Price in US Dollars',), ("2010-01-01",)])
# Out:
# Date                2010-01-01
# Country              Argentina
# Price in US Dollars       1.84

# %%
bigmac2.loc[('Price in US Dollars',), ("2010-01-01","Sri Lanka"):("2010-01-01","Ukraine")]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %% [markdown]
# #### The .swaplevel() Method

# %%
bigmac.swaplevel()


bigmac.swaplevel('Date', 'Country')
bigmac.swaplevel('Country', 'Date')
bigmac.swaplevel(0, 1)
bigmac.swaplevel(1, 0)
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# #### The .stack() Method

# %%
world = pd.read_csv("files/worldstats.csv", index_col=['country', 'year'])

# %%
world.head()
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12

# %%
# shift columns to row index

world.stack()

type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world2 = world.stack().to_frame()

world2
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
world2.loc[('Arab World', 2015, 'Population')]
# Out:
# 0    392022276.0
# Name: (Arab World, 2015, Population), dtype: float64

# %%
# shift row index to column index

world2 = world2.unstack()

# %%
# world2.index

# world2.loc[('Arab World', 2015, 'Population')]

world2
# Out:
#                                0                                            \
#                       Population
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
# world2.loc[('Afghanistan',), ("Population", 1960)]


world2.index

world2.loc[('Afghanistan',), (0, "Population", 1960)]

# world2.columns
# Out:
# country
# Afghanistan    8994793.0
# Name: (0, Population, 1960), dtype: float64

# %%
sales = pd.read_csv("files/salesmen.csv", parse_dates=['Date'])

# %%
sales
# Out:
#            Date Salesman  Revenue
# 0    2016-01-01      Bob     7172
# 1    2016-01-02      Bob     6362
# 2    2016-01-03      Bob     5982
# 3    2016-01-04      Bob     7917
# 4    2016-01-05      Bob     7837
# ...         ...      ...      ...
# 1825 2016-12-27    Oscar      835
# 1826 2016-12-28    Oscar     3073
# 1827 2016-12-29    Oscar     6424
# 1828 2016-12-30    Oscar     7088
# 1829 2016-12-31    Oscar     8408
#
# [1830 rows x 3 columns]

# %%
#pivot

sales.pivot(index='Date', columns='Salesman', values='Revenue')
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
foods = pd.read_csv("files/foods.csv")
foods
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
foods.pivot_table(values='Spend', index='Gender', aggfunc='mean')
# foods.pivot_table(values='Spend', index='Gender', aggfunc='sum')
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values='Spend', index='Item', aggfunc='mean')
# Out:
#                Spend
# Item
# Burger     49.780321
# Burrito    49.228810
# Chalupa    52.003537
# Donut      46.838289
# Ice Cream  50.494261
# Sushi      52.668253

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], aggfunc='mean')
# Out:
#                       Spend
# Gender Item
# Female Burger     49.930488
#        Burrito    50.092000
#        Chalupa    54.635000
#        Donut      49.926316
#        Ice Cream  49.788519
#        Sushi      50.355699
# Male   Burger     49.613919
#        Burrito    48.344819
#        Chalupa    49.186761
#        Donut      43.649565
#        Ice Cream  51.096000
#        Sushi      55.614384

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns='City', aggfunc='mean')
# Out:
# City               New York  Philadelphia   Stamford
# Gender Item
# Female Burger     51.626667     52.878710  45.037778
#        Burrito    42.563043     52.098571  53.532647
#        Chalupa    46.135789     52.291563  64.094000
#        Donut      46.670323     54.642000  48.734118
#        Ice Cream  56.356296     46.225625  46.910455
#        Sushi      47.751290     58.096000  45.622187
# Male   Burger     58.822273     44.675238  46.424516
#        Burrito    55.976000     43.764333  46.438929
#        Chalupa    49.110800     48.444783  50.011304
#        Donut      44.842333     37.859394  49.004483
#        Ice Cream  55.297586     53.445610  42.368800
#        Sushi      51.709259     49.852857  70.434444

# %%
foods.pivot_table(values='Spend', index=['Gender','Item'], columns=['Frequency','City'], aggfunc='mean')
# Out:
# Frequency             Daily                            Monthly               \
# City               New York Philadelphia   Stamford   New York Philadelphia
# Gender Item
# Female Burger     43.778333    77.226667  48.220000  57.286667    53.762500
#        Burrito    44.890000    53.595000  39.126000  40.913333    17.140000
#        Chalupa    43.190000    23.490000  95.700000  79.185000    72.490000
#        Donut      39.841667    61.850000  41.450000  71.132500    50.250000
#        Ice Cream  65.547500    59.230000  46.440000  46.265000    37.255000
#        Sushi      40.535000    58.088333  56.181429  46.580000    78.710000
# Male   Burger     63.892000    37.566667  49.430000  62.430000    71.046667
#        Burrito    78.736667    41.440000  69.057500  49.180000    29.860000
#        Chalupa    27.045000    68.702500  48.160000  66.752000    45.350000
#        Donut      46.000000    47.677500  64.710000  45.932500    51.858000
# ...

# %%
## pd.melt

# revese of pivot

# %%
salesdata = pd.read_csv("files/quarters.csv")

# %%
salesdata
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(salesdata, id_vars='Salesman', var_name='Quarter', value_name='Revenue')
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
