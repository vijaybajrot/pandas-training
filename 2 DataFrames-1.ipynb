# %% [markdown]
# ## DataFrames

# %%
import pandas as pd

# %%
# Players Info
nba = pd.read_csv("files/nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### Basics

# %%
nba.head()
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %% [markdown]
# #### Columns

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
# dataframe info
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# #### Revenue Example

# %%
rev = pd.read_csv("files/revenue.csv", index_col="Date")

# %%
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
# Sum as Row wise, like for Date, use axis=1 or axis="columns"
#rev.sum(axis=1)
rev.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
#### Select One Column from a DataFrame

# %%
# Dot way
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
# Recomment

nba['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
type(nba['Name'])
# Out:
# pandas.core.series.Series

# %%
nba['Name'].head(3)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# Name: Name, dtype: object

# %% [markdown]
# #### Select Two or More Columns from a DataFrame

# %%
nba[["Name", "Team"]]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
type(nba[["Name", "Team"]])
# Out:
# pandas.core.frame.DataFrame

# %%
nba[["Name", "Team"]].head(3)
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics

# %%
# Change Order
nba[["Team", "Name"]].head(3)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland

# %% [markdown]
# #### Add New Column to DataFrame

# %%
# It will throw error
nba['Sport']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sport'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-bb909fd1a300> in <module>
# ...

# %%
# Create a new column with default value
nba['Sport'] = "Basketball"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
# add column using insert method

nba.insert(3, column= "League", value="National BasketBall Association")

# %%
nba.head(3)
# Out:
#             Name            Team  Number                           League  \
# 0  Avery Bradley  Boston Celtics     0.0  National BasketBall Association
# 1    Jae Crowder  Boston Celtics    99.0  National BasketBall Association
# 2   John Holland  Boston Celtics    30.0  National BasketBall Association
#
#   Position   Age Height  Weight            College     Salary       Sport
# 0       PG  25.0    6-2   180.0              Texas  7730337.0  Basketball
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2       SG  27.0    6-5   205.0  Boston University        NaN  Basketball

# %%
#### Broadcasting Operations on DataFrames

# %%
# It will add 5 to each item
nba['Age'].add(5)
nba['Age'] + 5 #output same as above
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
#        ...
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
#sub
nba['Salary'].sub(5000)
nba['Salary'] - 5000 #output same as above
# Out:
# 0      7725337.0
# 1      6791117.0
# 2            NaN
# 3      1143640.0
# 4      4995000.0
#          ...
# 453    2428333.0
# 454     895000.0
# 455    2895000.0
# 456     942276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
#multipy

#.453592 convert weight to pounds to kg

nba['Weight'].mul(.453592)

#add new column with updated series
nba['Weight_In_KG'] = nba['Weight'].mul(.453592)

# %%
nba.head()
# Out:
#             Name            Team  Number                           League  \
# 0  Avery Bradley  Boston Celtics     0.0  National BasketBall Association
# 1    Jae Crowder  Boston Celtics    99.0  National BasketBall Association
# 2   John Holland  Boston Celtics    30.0  National BasketBall Association
# 3    R.J. Hunter  Boston Celtics    28.0  National BasketBall Association
# 4  Jonas Jerebko  Boston Celtics     8.0  National BasketBall Association
#
#   Position   Age Height  Weight            College     Salary       Sport  \
# 0       PG  25.0    6-2   180.0              Texas  7730337.0  Basketball
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2       SG  27.0    6-5   205.0  Boston University        NaN  Basketball
# 3       SG  22.0    6-5   185.0      Georgia State  1148640.0  Basketball
# 4       PF  29.0   6-10   231.0                NaN  5000000.0  Basketball
#
#    Weight_In_KG
# 0     81.646560
# 1    106.594120
# 2     92.986360
# ...

# %% [markdown]
# #### Drop DataFrame Rows with Null Values

# %%
# it will remove all rows, where any of column have NaN value
nba.dropna()
# Out:
#               Name            Team  Number                           League  \
# 0    Avery Bradley  Boston Celtics     0.0  National BasketBall Association
# 1      Jae Crowder  Boston Celtics    99.0  National BasketBall Association
# 3      R.J. Hunter  Boston Celtics    28.0  National BasketBall Association
# 6    Jordan Mickey  Boston Celtics    55.0  National BasketBall Association
# 7     Kelly Olynyk  Boston Celtics    41.0  National BasketBall Association
# ..             ...             ...     ...                              ...
# 449    Rodney Hood       Utah Jazz     5.0  National BasketBall Association
# 451  Chris Johnson       Utah Jazz    23.0  National BasketBall Association
# 452     Trey Lyles       Utah Jazz    41.0  National BasketBall Association
# 453   Shelvin Mack       Utah Jazz     8.0  National BasketBall Association
# 456    Jeff Withey       Utah Jazz    24.0  National BasketBall Association
#
# ...

# %%
# Remove only where all columns have NaN value (ROW Wise)
nba.dropna(how="all")

# nba.dropna(how="all", inplace=True)
# Out:
#               Name            Team  Number                           League  \
# 0    Avery Bradley  Boston Celtics     0.0  National BasketBall Association
# 1      Jae Crowder  Boston Celtics    99.0  National BasketBall Association
# 2     John Holland  Boston Celtics    30.0  National BasketBall Association
# 3      R.J. Hunter  Boston Celtics    28.0  National BasketBall Association
# 4    Jonas Jerebko  Boston Celtics     8.0  National BasketBall Association
# ..             ...             ...     ...                              ...
# 453   Shelvin Mack       Utah Jazz     8.0  National BasketBall Association
# 454      Raul Neto       Utah Jazz    25.0  National BasketBall Association
# 455   Tibor Pleiss       Utah Jazz    21.0  National BasketBall Association
# 456    Jeff Withey       Utah Jazz    24.0  National BasketBall Association
# 457            NaN             NaN     NaN  National BasketBall Association
#
# ...

# %%
nba.tail(3)
# Out:
#              Name       Team  Number                           League  \
# 455  Tibor Pleiss  Utah Jazz    21.0  National BasketBall Association
# 456   Jeff Withey  Utah Jazz    24.0  National BasketBall Association
# 457           NaN        NaN     NaN  National BasketBall Association
#
#     Position   Age Height  Weight College     Salary       Sport  Weight_In_KG
# 455        C  26.0    7-3   256.0     NaN  2900000.0  Basketball    116.119552
# 456        C  26.0    7-0   231.0  Kansas   947276.0  Basketball    104.779752
# 457      NaN   NaN    NaN     NaN     NaN        NaN  Basketball           NaN

# %%
# Drop Column Wise

nba.dropna(axis=1)
nba.dropna(axis="columns")
nba.tail()
# Out:
#              Name       Team  Number                           League  \
# 453  Shelvin Mack  Utah Jazz     8.0  National BasketBall Association
# 454     Raul Neto  Utah Jazz    25.0  National BasketBall Association
# 455  Tibor Pleiss  Utah Jazz    21.0  National BasketBall Association
# 456   Jeff Withey  Utah Jazz    24.0  National BasketBall Association
# 457           NaN        NaN     NaN  National BasketBall Association
#
#     Position   Age Height  Weight College     Salary       Sport  Weight_In_KG
# 453       PG  26.0    6-3   203.0  Butler  2433333.0  Basketball     92.079176
# 454       PG  24.0    6-1   179.0     NaN   900000.0  Basketball     81.192968
# 455        C  26.0    7-3   256.0     NaN  2900000.0  Basketball    116.119552
# 456        C  26.0    7-0   231.0  Kansas   947276.0  Basketball    104.779752
# 457      NaN   NaN    NaN     NaN     NaN        NaN  Basketball           NaN

# %%
# Remove for specific columns

nba.dropna(subset=['Salary'])
nba.dropna(subset=['Salary','College'])
# Out:
#               Name            Team  Number                           League  \
# 0    Avery Bradley  Boston Celtics     0.0  National BasketBall Association
# 1      Jae Crowder  Boston Celtics    99.0  National BasketBall Association
# 3      R.J. Hunter  Boston Celtics    28.0  National BasketBall Association
# 6    Jordan Mickey  Boston Celtics    55.0  National BasketBall Association
# 7     Kelly Olynyk  Boston Celtics    41.0  National BasketBall Association
# ..             ...             ...     ...                              ...
# 449    Rodney Hood       Utah Jazz     5.0  National BasketBall Association
# 451  Chris Johnson       Utah Jazz    23.0  National BasketBall Association
# 452     Trey Lyles       Utah Jazz    41.0  National BasketBall Association
# 453   Shelvin Mack       Utah Jazz     8.0  National BasketBall Association
# 456    Jeff Withey       Utah Jazz    24.0  National BasketBall Association
#
# ...

# %%
#### Change Data Type
# Chnage a datatype also effect memory usage
# like int uses less memory according to float

# %%
# fill NaN as 0 in salary to avoid errors
nba['Salary'].fillna(0, inplace=True)
nba['Salary']

# %%
# Change datatype
nba['Salary'] = nba['Salary'].astype('int')


nba['Salary'].head()
# Out:
# 0    7730337
# 1    6796117
# 2          0
# 3    1148640
# 4    5000000
# Name: Salary, dtype: int64

# %%
# Category datatype
# Its like a enum data type, it uses to store uniqe or similar values
# Here we have Position column that can be a "category" datatype

# to check uniqueness
nba['Position'].nunique()
# Out:
# 5

# %%
nba['Position'] = nba['Position'].astype('category')

# It will show same output,

# %%
#### Sort a DataFrame with the sort_values

# %%
nba.sort_values("Salary")

nba.sort_values("Salary", ascending=False)
# nba.sort_values("Salary", ascending=False, inplace=True)

nba.sort_values("Salary", ascending=False, na_position="first")
# nba.sort_values("Salary", ascending=False, na_position="last")
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
## Sort by muti columns

# %%
nba.sort_values(["Team", "Name"])

# order
nba.sort_values(["Team", "Name"], ascending=False)
nba.sort_values(["Team", "Name"], ascending=[True, False])
# nba.sort_values(["Team", "Name"], ascending=[True, False], inplace=True)
# Out:
#                  Name                Team  Number Position   Age Height  \
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# ..                ...                 ...     ...      ...   ...    ...
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 322   260.0             NaN   1000000.0
# ...

# %%
#### sort_index method

# %%
nba.sort_index()

# nba.sort_index(ascending=False, inplace=True)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### rank method

# %%
nba['Salary'] = nba['Salary'].fillna(0).astype('int')

nba['Salary_Rank'] = nba['Salary'].rank(ascending = False).astype('int')

# %%
nba.head()
nba.sort_values('Salary', ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 269     Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 2       John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight            College    Salary  Salary_Rank
# ...
